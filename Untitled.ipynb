# %%
import pandas as pd

# %%
df = pd.read_csv("vgsales-12-4-2019-short.csv", index_col = "Rank")
df.head()
# Out:
#                                Name     Genre ESRB_Rating Platform  \
# Rank
# 1                        Wii Sports    Sports           E      Wii
# 2                 Super Mario Bros.  Platform         NaN      NES
# 3                    Mario Kart Wii    Racing           E      Wii
# 4     PlayerUnknown's Battlegrounds   Shooter         NaN       PC
# 5                 Wii Sports Resort    Sports           E      Wii
#
#              Publisher         Developer  Critic_Score  User_Score  \
# Rank
# 1             Nintendo      Nintendo EAD           7.7         NaN
# 2             Nintendo      Nintendo EAD          10.0         NaN
# 3             Nintendo      Nintendo EAD           8.2         9.1
# 4     PUBG Corporation  PUBG Corporation           NaN         NaN
# 5             Nintendo      Nintendo EAD           8.0         8.8
#
#       Total_Shipped  Global_Sales  NA_Sales  PAL_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55792 entries, 1 to 55792
# Data columns (total 15 columns):
# Name             55792 non-null object
# Genre            55792 non-null object
# ESRB_Rating      23623 non-null object
# Platform         55792 non-null object
# Publisher        55792 non-null object
# Developer        55775 non-null object
# Critic_Score     6536 non-null float64
# User_Score       335 non-null float64
# Total_Shipped    1827 non-null float64
# Global_Sales     19415 non-null float64
# NA_Sales         12964 non-null float64
# PAL_Sales        13189 non-null float64
# JP_Sales         7043 non-null float64
# Other_Sales      15522 non-null float64
# Year             54813 non-null float64
# dtypes: float64(9), object(6)
# memory usage: 6.8+ MB

# %%
df.dtypes
# Out:
# Name              object
# Genre             object
# ESRB_Rating       object
# Platform          object
# Publisher         object
# Developer         object
# Critic_Score     float64
# User_Score       float64
# Total_Shipped    float64
# Global_Sales     float64
# NA_Sales         float64
# PAL_Sales        float64
# JP_Sales         float64
# Other_Sales      float64
# Year             float64
# dtype: object

# %%
df["Year"].fillna(0, inplace = True)

# %%
df["Year"] = df["Year"].astype("int")

# %% [markdown]
# # Since, there are not so many ratings, I saved some some memory here

# %%
df["ESRB_Rating"].unique()
# Out:
# array(['E', nan, 'M', 'E10', 'T', 'RP', 'EC', 'AO', 'KA'], dtype=object)

# %%
df["ESRB_Rating"] = df["ESRB_Rating"].astype("category")

# %% [markdown]
# # There was so much data missing in certain columns, so I decided to delete some

# %%
del df["User_Score"]

# %%
del df["Global_Sales"]

# %%
del df["NA_Sales"]

# %%
del df["PAL_Sales"]

# %%
del df["JP_Sales"]

# %%
del df["Other_Sales"]

# %% [markdown]
# # Top selling games

# %%
df["Total_Shipped"].nlargest(3)
# Out:
# Rank
# 1    82.86
# 2    40.24
# 3    37.14
# Name: Total_Shipped, dtype: float64

# %%
df.loc[1]
# Wii Sports
# Out:
# Name               Wii Sports
# Genre                  Sports
# ESRB_Rating                 E
# Platform                  Wii
# Publisher            Nintendo
# Developer        Nintendo EAD
# Critic_Score              7.7
# Total_Shipped              82
# Year                     2006
# Name: 1, dtype: object

# %%
df["Total_Shipped"].nsmallest(1)
# Out:
# Rank
# 16761    0.03
# Name: Total_Shipped, dtype: float64

# %%
df.loc[16761]
# OutRun 2006: Coast 2 Coast
# Out:
# Name             OutRun 2006: Coast 2 Coast
# Genre                                Racing
# ESRB_Rating                               E
# Platform                                 XB
# Publisher                              Sega
# Developer                      Sumo Digital
# Critic_Score                            NaN
# Total_Shipped                             0
# Year                                   2006
# Name: 16761, dtype: object

# %% [markdown]
# # Games that did great at the critic score

# %%
df["Critic_Score"].nlargest(5)
# Out:
# Rank
# 2      10.0
# 10     10.0
# 74     10.0
# 80     10.0
# 107    10.0
# Name: Critic_Score, dtype: float64

# %%
df.loc[[2, 10, 14, 74, 80, 107]]
# Out:
#                      Name       Genre ESRB_Rating Platform       Publisher  \
# Rank
# 2       Super Mario Bros.    Platform         NaN      NES        Nintendo
# 10              Minecraft        Misc         NaN       PC          Mojang
# 14             Nintendogs  Simulation           E       DS        Nintendo
# 74    Grand Theft Auto IV      Action           M     X360  Rockstar Games
# 80    Grand Theft Auto IV      Action           M      PS3  Rockstar Games
# 107      Super Mario Kart      Racing           E     SNES        Nintendo
#
#            Developer  Critic_Score  Total_Shipped  Year
# Rank
# 2       Nintendo EAD          10.0          40.24  1985
# 10         Mojang AB          10.0          30.01  2010
# 14      Nintendo EAD           8.4          23.96  2005
# 74    Rockstar North          10.0            NaN  2008
# 80    Rockstar North          10.0            NaN  2008
# 107     Nintendo EAD          10.0           8.76  1992

# %% [markdown]
# # All games by Nintendo ordered by "Total_Shipped"

# %%
df["Total_Shipped"].fillna(0, inplace = True)

# %%
df["Total_Shipped"] = df["Total_Shipped"].astype("int")

# %%
df2 = df[["Publisher" , "Total_Shipped"]].sort_values(by = "Total_Shipped", ascending = False)

# %%
df2.head()
# Out:
#              Publisher  Total_Shipped
# Rank
# 1             Nintendo             82
# 2             Nintendo             40
# 3             Nintendo             37
# 4     PUBG Corporation             36
# 5             Nintendo             33

# %%
mask = df[df["Publisher"] == "Nintendo"]

# %%
mask
# Out:
#                                                     Name             Genre  \
# Rank
# 1                                             Wii Sports            Sports
# 2                                      Super Mario Bros.          Platform
# 3                                         Mario Kart Wii            Racing
# 5                                      Wii Sports Resort            Sports
# 6                     Pokemon Red / Green / Blue Version      Role-Playing
# 7                                  New Super Mario Bros.          Platform
# 8                                                 Tetris            Puzzle
# 9                              New Super Mario Bros. Wii          Platform
# 11                                             Duck Hunt           Shooter
# 12                                              Wii Play              Misc
# 14                                            Nintendogs        Simulation
# ...

# %%
mask["Total_Shipped"].sum()
# Out:
# 1666

# %% [markdown]
# # The total of games in this dataset

# %%
df["Name"].nunique()
# Out:
# 37102

# %% [markdown]
# # All the platforms in this dataset

# %%
df["Platform"].unique()
# Out:
# array(['Wii', 'NES', 'PC', 'GB', 'DS', 'X360', 'SNES', 'PS3', 'PS4',
#        '3DS', 'PS2', 'GBA', 'NS', 'GEN', 'N64', 'PS', 'XOne', 'WiiU',
#        'XB', 'PSP', '2600', 'GC', 'GBC', 'PSN', 'PSV', 'DC', 'SAT', 'SCD',
#        'WS', 'XBL', 'Amig', 'VC', 'NG', 'WW', 'PCE', '3DO', 'GG', 'OSX',
#        'PCFX', 'Mob', 'And', 'Ouya', 'DSiW', 'MS', 'DSi', 'VB', 'Linux',
#        'MSD', 'C128', 'AST', 'Lynx', '7800', '5200', 'S32X', 'MSX', 'FMT',
#        'ACPC', 'C64', 'BRW', 'AJ', 'ZXS', 'NGage', 'GIZ', 'WinP', 'iQue',
#        'iOS', 'Arc', 'ApII', 'Aco', 'BBCM', 'TG16', 'CDi', 'CD32', 'Int'],
#       dtype=object)

# %% [markdown]
# # Information for some succesfull platforms: Xbox 360, Playstation 3 and Wii

# %%
df[df["Platform"]  == "X360"].nunique()
# Out:
# Name             1696
# Genre              16
# ESRB_Rating         6
# Platform            1
# Publisher         179
# Developer         609
# Critic_Score       68
# Total_Shipped       8
# Year               33
# dtype: int64

# %%
df[df["Platform"]  == "PS3"].nunique()
# Out:
# Name             1859
# Genre              17
# ESRB_Rating         5
# Platform            1
# Publisher         212
# Developer         595
# Critic_Score       62
# Total_Shipped       6
# Year               36
# dtype: int64

# %%
df[df["Platform"]  == "Wii"].nunique()
# Out:
# Name             1667
# Genre              16
# ESRB_Rating         6
# Platform            1
# Publisher         163
# Developer         635
# Critic_Score       61
# Total_Shipped      19
# Year               33
# dtype: int64
